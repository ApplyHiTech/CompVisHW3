# %%
#Homework 3 Task 3

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %matplotlib inline

img1_trees = mpimg.imread('HW3/Images/Q3/15.bmp')
img2_patches = mpimg.imread('HW3/Images/Q3/171.bmp')
img3_treeboat = mpimg.imread('HW3/Images/Q3/45.bmp')
img4_boat = mpimg.imread('HW3/Images/Q3/81.bmp')

plt.imshow(imgimg1_trees,cmap="gray")
plt.imshow(imgimg1_trees,cmap="gray")
plt.imshow(img4_boat,cmap="gray")
plt.imshow(img4_boat,cmap="gray")
